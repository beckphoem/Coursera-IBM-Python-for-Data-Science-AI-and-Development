# %% [markdown]
# # String Operations

# %% [markdown]
# ## Objectives
#
# After completing this lab you will be able to:
#
# - Work with Strings
# - Perform operations on String
# - Manipulate Strings using indexing and escape sequences

# %% [markdown]
# ## Table of Contents
#
# - [What are Strings?](#1)
# - [Indexing](#2)
# 	- [Negative Indexing](#3)
# 	- [Slicing](#4)
# 	- [Stride](#5)
# 	- [Concatenate Strings](#6)
#
# - [Escape Sequences](#7)
# - [String manipulation Operations](#8)
# - [Quiz on Strings](#9)

# %% [markdown]
# # What are Strings <a id = "1"></a>

# %%
# Use quotations marks for defining string

"Michael Jackson"
# Out:
# 'Michael Jackson'

# %% [markdown]
# We can also use single quotation marks:

# %%
# Use single quotation marks for defining string

'Michael Jackson'
# Out:
# 'Michael Jackson'

# %% [markdown]
# A string can be a combination of spaces and digits:

# %%
# Special characters in string

'1 2 3 4 5 6'
# Out:
# '1 2 3 4 5 6'

# %%
# Special characters in string

'@#2_#]&*^%$'
# Out:
# '@#2_#]&*^%$'

# %% [markdown]
# We can input our string using the print statement:

# %%
# Print the string

print("hello!")
# Out:
# hello!

# %% [markdown]
# # Indexing <a id = "2"></a>

# %% [markdown]
# It is helpful to think of a string as an ordered sequence. Each element in the sequence can be accessed using an index represented by the array of numbers:
#
# ![1.png](attachment:1.png)

# %% [markdown]
# The first index can be accessed as follows:

# %% [markdown]
# > [Tip]: Because indexing starts at 0, it means the first index is on the index 0.

# %%
# Print the first element in the string

name = "Michael Jackson"
print(name[0])
# Out:
# M

# %% [markdown]
# We can access index 6:

# %%
# Print the element on index 6 in the string

print(name[6])
# Out:
# l

# %% [markdown]
# Moreover, we can access the 13th index:

# %%
# Print the element on the 13th index in the string

print(name[13])
# Out:
# o

# %% [markdown]
# ## Indexing: Negative Indexing <a id = "3"></a>

# %% [markdown]
# We can also use negative indexing with strings:
#
# ![2.png](attachment:2.png)

# %% [markdown]
# Negative index can help us to count the element from the end of the string.

# %% [markdown]
# The last element is given by the index -1:

# %%
# Print the last element in the string

print(name[-1])
# Out:
# n

# %% [markdown]
# The first element can be obtained by index -15:

# %%
# Print the first element in the string 

print(name[-15])
# Out:
# M

# %% [markdown]
# We can find the number of characters in a string by using `len`, short for length:

# %%
# Find the length of string

len("Michael Jackson")
# Out:
# 15

# %% [markdown]
# ## Indexing: Slicing <a id = "4"></a>

# %% [markdown]
# We can obtain multiple characters from a string using slicing, we can obtain the 0 to 4th and 8th to the 12th element:
#
# ![3.png](attachment:3.png)

# %% [markdown]
# > [Tip]: When taking the slice, the first number means the index (start at 0), and the second number means the length from the index to the last element you want (start at 1)

# %%
# Take the slice on variable name with only index 0 to index 3

name[0:4]
# Out:
# 'Mich'

# %%
# Take the slice on variable name with only index 8 to index 11

name[8:12]
# Out:
# 'Jack'

# %% [markdown]
# ## Indexing: Stride <a id = "5"></a>

# %% [markdown]
# #### Stride
#
# We can also input a stride value as follows, with the '2' indicating that we are selecting every second variable:
#
# ![4.png](attachment:4.png)

# %%
# Get every second element. The element on index 1, 3 , 5 , ...

name[::2]
# Out:
# 'McalJcsn'

# %% [markdown]
# ## Indexing: Concatenate Strings <a id = "6"></a>

# %% [markdown]
# #### Concatenate Strings

# %% [markdown]
# We can concatenate or combine strings by using the addition symbols, and the result is a new string that is a combination of both:

# %%
# Concatenate two strings

statement = name + "is the best"

statement
# Out:
# 'Michael Jacksonis the best'

# %% [markdown]
# To replicate values of a string we simply multiply the string by the number of times we would like to replicate it. In this case, the number is three. The result is a new string, and this new string consists of three copies of the original string:

# %%
# Print the string for 3 times

3 * "Michael Jackson"
# Out:
# 'Michael JacksonMichael JacksonMichael Jackson'

# %% [markdown]
# You can create a new stirng by setting it to the original variable. Concatenated with a new string, the result is a new string that changes from Michael Jackson to "Michael Jackson is the best"

# %%
# Concatenate strings

name = "Michael Jackson"
name = name + "is the best"
name
# Out:
# 'Michael Jacksonis the best'

# %% [markdown]
# # Escape sequences <a id = "7"></a>

# %% [markdown]
# Back slashes represent the beginning of escape sequences. Escpae sequences represent strings that my be difficult to input. For example, `\n` represents a new line. the output is given by a new line after the `\n` is encountered:

# %%
# New line escape sequence

print("Machael Jackson \n is the best")
# Out:
# Machael Jackson
#  is the best

# %% [markdown]
# Similarly, back slash `\t` represented a tab:

# %%
# Tab escape sequence

print("Michael Jackosn \t is the best")
# Out:
# Michael Jackosn 	 is the best

# %% [markdown]
# If you want to place a back slash in your string, use a double back slash:

# %%
# Include back slash in string:

print("Michael Jackson \\ is the best")
# Out:
# Michael Jackson \ is the best

# %% [markdown]
# We can also place an "r" before the string to display the backslash:

# %%
# r will tell python that string will be display as raw string

print(r"Michael Jackson \ is the best")
# Out:
# Michael Jackson \ is the best

# %% [markdown]
# # String Manipulation Operations <a id = "8"></a>

# %% [markdown]
# There are many string operation methods in Python that can be used to manipulate the data.
#
# Let's try with the method `upper`; this method converts lower case characters to upper case characters:

# %%
# Convert all the characters in string to upper case

a = "Thriller is the sixth studio album"
print("before uppder:", a)
b = a.upper()
print("After uppder:", b)
# Out:
# before uppder: Thriller is the sixth studio album
# After uppder: THRILLER IS THE SIXTH STUDIO ALBUM

# %% [markdown]
# The method `replace` replaces a segment of the string, i.e. substring with a new string. We input the part of the string we would like to change. The second argument is what we would like to exchange the segment with, and the result is a new string with the segment changed:

# %%
# Replace the old substring with the new target substring is the segment has been found in the string

a = "Michael Jackson is the best"

b = a.replace('Michael', 'Janet')

# %%
b
# Out:
# 'Janet Jackson is the best'

# %% [markdown]
# The method `find` finds a sub-string. The argument is the substring you would like to find, and the output is the first index of the sequence. We can find the sub-string `jack` or `el`.

# %% [markdown]
# ![5.png](attachment:5.png)

# %%
# Find the substirng in the string. Only the index of the first element of substring in string will be the output

name = "Michael Jackon"
name.find('el')
# Out:
# 5

# %% [markdown]
# # Quiz on Strings <a id = "9"></a>
